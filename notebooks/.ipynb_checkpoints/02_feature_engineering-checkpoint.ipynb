# %% [markdown]
# # Feature Engineering Notebook
#
# This notebook demonstrates the feature engineering step. It aggregates transaction-level data into customer-level features and writes the results to the run folder.
#
# Set `run_id` to the identifier of your pipeline run before executing the code cell.

# %%
from src.pipeline.feature_engineering import run_feature_engineering
# Set your run identifier here
run_id = 'my_run_id'
run_feature_engineering(run_id)

# %%
import csv
from pathlib import Path
features_path = Path('artifacts/runs')/run_id/'step2_feature_engineering'/'data'/'customer_features.csv'
with open(features_path, newline='', encoding='utf-8') as f:
    reader = csv.reader(f)
    header = next(reader)
    rows = [next(reader) for _ in range(3)]  # preview first 3 rows
header, rows
