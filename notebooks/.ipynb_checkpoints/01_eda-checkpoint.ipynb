# %% [markdown]
# # EDA Notebook
#
# This notebook reproduces the Exploratory Data Analysis (EDA) step of the pipeline. It reads the Gold wide sales table for a given run, computes summary statistics without exposing personally identifiable information, and writes the results to the artifacts folder.
#
# Replace `my_run_id` below with the run identifier you used when executing the pipeline.

# %%
from src.pipeline.eda import run_eda
# Set your run identifier here
run_id = 'my_run_id'
run_eda(run_id)

# %%
import json
from pathlib import Path
summary_path = Path('artifacts/runs')/run_id/'step1_eda'/'data'/'eda_summary.json'
summary = json.loads(summary_path.read_text())
summary
